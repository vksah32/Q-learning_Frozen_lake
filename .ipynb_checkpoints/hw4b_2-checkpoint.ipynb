# %% [markdown]
# # Problem Set 4b - Frozen Lake Problem

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import random

# %% [markdown]
# ## Load matrices

# %%
from scipy.io import loadmat

def load(fname):
    matdict = loadmat(fname)
    
    fl = np.array(matdict["FL"])

    flcost = np.array(matdict["FLCost"])
    return fl, flcost


FL,FL_cost  = load("matrices_4b2.mat")

n = FL_cost.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3618d41f766e> in <module>()
#      10
#      11
# ---> 12 FL,FL_cost  = load("matrices_4b2.mat")
#      13
#      14 n = FL_cost.shape[0]
#
# <ipython-input-1-3618d41f766e> in load(fname)
#       4     matdict = loadmat(fname)
#       5
# ----> 6     fl = np.array(matdict["FL"])
#       7
#       8     flcost = np.array(matdict["FLCost"])
#
# NameError: global name 'np' is not defined

# %%
#define directions
up = 0
right = 1
down = 2
left = 3
actions = ["up","right", "down", "left"]

num_actions = 4

# %% [markdown]
# # Look at Rewards heatmap

# %%
from seaborn import heatmap
heatmap(FL_cost)

# %% [markdown]
# # Define helper functions to move around in the grid

# %%
def get_next_action(current_state, action): 
    return (np.random.multinomial(1, FL[current_state[0], current_state[1], action, :])).argmax()

def get_next_state(current_state, action):
    if action == left:
        return (current_state[0], max(0, current_state[1]-1))
    if action == right:
        return (current_state[0], min(n-1, current_state[1]+1))
    if action == down:
        return (min(n-1, current_state[0]+1),  current_state[1])
    if action == up:
        return (max(0, current_state[0]-1),  current_state[1])
    
def step(current_state, action):
    next_action = get_next_action(current_state, action)
    next_state = get_next_state(current_state, next_action)
   
    return next_action, next_state

# %% [markdown]
# # Implement Q -Learning

# %%
#implement Q learning
lr = 0.1 #learning rate
gamma = 1 # discount factor
action_epsilon = 0.80
num_episodes = 5000 #number of iterations

Q = np.random.rand(n, n,num_actions) * 0.001

# print Q

start_state = (0,0)
# current_state = (0,0)
end_state = (n-1,n-1)

# score = []
for i in range(num_episodes):
    start_time = time.time()
    print "Now", i,
    current_state = (0,0)
    j = 0
#     while current_state != end_state:
    while current_state != end_state:
        #get the next action based on some probability 10% take random action, 90% take best action
        action_random_value = random.random()
        if action_random_value < action_epsilon:
            action = np.argmax(Q[current_state[0],current_state[1],:])
        else:
            action = random.randint(0,3)
        
        actual_next_action, next_state = step(current_state, action)
        reward = FL_cost[next_state[0], next_state[1]]
        current_Q = Q[current_state[0],current_state[1], action]
        Q[current_state[0],current_state[1], action] = current_Q +  lr*(reward + gamma * (np.max(Q[next_state[0], next_state[1],:]) - current_Q))
        score = [current_state, Q[current_state[0],current_state[1], action], action]
        current_state = next_state
        if current_state == end_state:
            print "reached end"
            break
    print("elapsed time, ", time.time() - start_time)
# Out:
# Now 0 reached end
# ('elapsed time, ', 0.06045985221862793)
# Now 1 reached end
# ('elapsed time, ', 0.054028987884521484)
# Now 2 reached end
# ('elapsed time, ', 0.029853105545043945)
# Now 3 reached end
# ('elapsed time, ', 0.007447004318237305)
# Now 4 reached end
# ('elapsed time, ', 0.009601116180419922)
# Now 5 reached end
# ('elapsed time, ', 0.004950046539306641)
# Now 6 reached end
# ('elapsed time, ', 0.026374101638793945)
# Now 7 reached end
# ('elapsed time, ', 0.005987882614135742)
# Now 8 reached end
# ('elapsed time, ', 0.011246919631958008)
# Now 9 reached end
# ('elapsed time, ', 0.007819890975952148)
# Now 10 reached end
# ('elapsed time, ', 0.015511035919189453)
# Now 11 reached end
# ('elapsed time, ', 0.051824092864990234)
# Now 12 reached end
# ('elapsed time, ', 0.019464969635009766)
# Now 13 reached end
# ('elapsed time, ', 0.07168292999267578)
# Now 14 reached end
# ('elapsed time, ', 0.007749080657958984)
# Now 15 reached end
# ('elapsed time, ', 0.013048171997070312)
# Now 16 reached end
# ('elapsed time, ', 0.008650064468383789)
# Now 17 reached end
# ('elapsed time, ', 0.012351036071777344)
# Now 18 reached end
# ('elapsed time, ', 0.02603912353515625)
# Now 19 reached end
# ('elapsed time, ', 0.01709890365600586)
# Now 20 reached end
# ('elapsed time, ', 0.015568017959594727)
# Now 21 reached end
# ('elapsed time, ', 0.03244614601135254)
# Now 22 reached end
# ('elapsed time, ', 0.006022214889526367)
# Now 23 reached end
# ('elapsed time, ', 0.02146315574645996)
# Now 24 reached end
# ('elapsed time, ', 0.01594090461730957)
# Now 25 reached end
# ('elapsed time, ', 0.01244497299194336)
# Now 26 reached end
# ('elapsed time, ', 0.0166471004486084)
# Now 27 reached end
# ('elapsed time, ', 0.004513978958129883)
# Now 28 reached end
# ('elapsed time, ', 0.025928020477294922)
# Now 29 reached end
# ('elapsed time, ', 0.024485111236572266)
# Now 30 reached end
# ('elapsed time, ', 0.02299809455871582)
# Now 31 reached end
# ('elapsed time, ', 0.00542902946472168)
# Now 32 reached end
# ('elapsed time, ', 0.03432416915893555)
# Now 33 reached end
# ('elapsed time, ', 0.006373167037963867)
# Now 34 reached end
# ('elapsed time, ', 0.03964090347290039)
# Now 35 reached end
# ('elapsed time, ', 0.025796175003051758)
# Now 36 reached end
# ('elapsed time, ', 0.04848289489746094)
# Now 37 reached end
# ('elapsed time, ', 0.015055179595947266)
# Now 38 reached end
# ('elapsed time, ', 0.03290987014770508)
# Now 39 reached end
# ('elapsed time, ', 0.013313055038452148)
# Now 40 reached end
# ('elapsed time, ', 0.024147987365722656)
# Now 41 reached end
# ('elapsed time, ', 0.009546041488647461)
# Now 42 reached end
# ('elapsed time, ', 0.015981197357177734)
# Now 43 reached end
# ('elapsed time, ', 0.013928890228271484)
# Now 44 reached end
# ('elapsed time, ', 0.0062520503997802734)
# Now 45 reached end
# ('elapsed time, ', 0.04839301109313965)
# Now 46 reached end
# ('elapsed time, ', 0.0215609073638916)
# Now 47 reached end
# ('elapsed time, ', 0.07488894462585449)
# Now 48 reached end
# ('elapsed time, ', 0.018231868743896484)
# Now 49 reached end
# ('elapsed time, ', 0.03430008888244629)
# Now 50 reached end
# ('elapsed time, ', 0.018027067184448242)
# Now 51 reached end
# ('elapsed time, ', 0.015460014343261719)
# Now 52 reached end
# ('elapsed time, ', 0.0016241073608398438)
# Now 53 reached end
# ('elapsed time, ', 0.01593303680419922)
# Now 54 reached end
# ('elapsed time, ', 0.041613101959228516)
# Now 55 reached end
# ('elapsed time, ', 0.014202117919921875)
# Now 56 reached end
# ('elapsed time, ', 0.012458086013793945)
# Now 57 reached end
# ('elapsed time, ', 0.03809404373168945)
# Now 58 reached end
# ('elapsed time, ', 0.0182039737701416)
# Now 59 reached end
# ('elapsed time, ', 0.005079984664916992)
# Now 60 reached end
# ('elapsed time, ', 0.010318994522094727)
# Now 61 reached end
# ('elapsed time, ', 0.013377189636230469)
# Now 62 reached end
# ('elapsed time, ', 0.019963979721069336)
# Now 63 reached end
# ('elapsed time, ', 0.022388935089111328)
# Now 64 reached end
# ('elapsed time, ', 0.011492013931274414)
# Now 65 reached end
# ('elapsed time, ', 0.013051986694335938)
# Now 66 reached end
# ('elapsed time, ', 0.07609200477600098)
# Now 67 reached end
# ('elapsed time, ', 0.021663904190063477)
# Now 68 reached end
# ('elapsed time, ', 0.015443086624145508)
# Now 69 reached end
# ('elapsed time, ', 0.005476951599121094)
# Now 70 reached end
# ('elapsed time, ', 0.012384176254272461)
# Now 71 reached end
# ('elapsed time, ', 0.018782854080200195)
# Now 72 reached end
# ('elapsed time, ', 0.006951093673706055)
# Now 73 reached end
# ('elapsed time, ', 0.029366016387939453)
# Now 74 reached end
# ('elapsed time, ', 0.028211116790771484)
# Now 75 reached end
# ('elapsed time, ', 0.011946916580200195)
# Now 76 reached end
# ('elapsed time, ', 0.01593303680419922)
# Now 77 reached end
# ('elapsed time, ', 0.009628057479858398)
# Now 78 reached end
# ('elapsed time, ', 0.014801025390625)
# Now 79 reached end
# ('elapsed time, ', 0.008530139923095703)
# Now 80 reached end
# ('elapsed time, ', 0.007456064224243164)
# Now 81 reached end
# ('elapsed time, ', 0.005489826202392578)
# Now 82 reached end
# ('elapsed time, ', 0.009312868118286133)
# Now 83 reached end
# ('elapsed time, ', 0.009690999984741211)
# Now 84 reached end
# ('elapsed time, ', 0.00832509994506836)
# Now 85 reached end
# ('elapsed time, ', 0.0017271041870117188)
# Now 86 reached end
# ('elapsed time, ', 0.019796133041381836)
# Now 87 reached end
# ('elapsed time, ', 0.025346994400024414)
# Now 88 reached end
# ('elapsed time, ', 0.0038809776306152344)
# Now 89 reached end
# ('elapsed time, ', 0.006888151168823242)
# Now 90 reached end
# ('elapsed time, ', 0.008239984512329102)
# Now 91 reached end
# ('elapsed time, ', 0.004164934158325195)
# Now 92 reached end
# ('elapsed time, ', 0.007943153381347656)
# Now 93 reached end
# ('elapsed time, ', 0.03505897521972656)
# Now 94 reached end
# ('elapsed time, ', 0.0375821590423584)
# Now 95 reached end
# ('elapsed time, ', 0.008796930313110352)
# Now 96 reached end
# ('elapsed time, ', 0.011469125747680664)
# Now 97 reached end
# ('elapsed time, ', 0.015496969223022461)
# Now 98 reached end
# ('elapsed time, ', 0.01342010498046875)
# Now 99 reached end
# ('elapsed time, ', 0.0331120491027832)
# Now 100 reached end
# ('elapsed time, ', 0.013103961944580078)
# Now 101 reached end
# ('elapsed time, ', 0.0054569244384765625)
# Now 102 reached end
# ('elapsed time, ', 0.0051119327545166016)
# Now 103 reached end
# ('elapsed time, ', 0.00553584098815918)
# Now 104 reached end
# ('elapsed time, ', 0.00448918342590332)
# Now 105 reached end
# ('elapsed time, ', 0.02083420753479004)
# Now 106 reached end
# ('elapsed time, ', 0.005861043930053711)
# Now 107 reached end
# ('elapsed time, ', 0.0068280696868896484)
# Now 108 reached end
# ('elapsed time, ', 0.021914005279541016)
# Now 109 reached end
# ('elapsed time, ', 0.022587060928344727)
# Now 110 reached end
# ('elapsed time, ', 0.0031499862670898438)
# Now 111 reached end
# ('elapsed time, ', 0.010237932205200195)
# Now 112 reached end
# ('elapsed time, ', 0.017694950103759766)
# Now 113 reached end
# ('elapsed time, ', 0.007827997207641602)
# Now 114 reached end
# ('elapsed time, ', 0.0074160099029541016)
# Now 115 reached end
# ('elapsed time, ', 0.004754066467285156)
# Now 116 reached end
# ('elapsed time, ', 0.012418031692504883)
# Now 117 reached end
# ('elapsed time, ', 0.040001869201660156)
# Now 118 reached end
# ('elapsed time, ', 0.013262033462524414)
# Now 119 reached end
# ('elapsed time, ', 0.023180007934570312)
# Now 120 reached end
# ('elapsed time, ', 0.016505002975463867)
# Now 121 reached end
# ('elapsed time, ', 0.011673927307128906)
# Now 122 reached end
# ('elapsed time, ', 0.015226125717163086)
# Now 123 reached end
# ('elapsed time, ', 0.00755000114440918)
# Now 124 reached end
# ('elapsed time, ', 0.01641702651977539)
# Now 125 reached end
# ('elapsed time, ', 0.018023014068603516)
# Now 126 reached end
# ('elapsed time, ', 0.009505033493041992)
# Now 127 reached end
# ('elapsed time, ', 0.0065479278564453125)
# Now 128 reached end
# ('elapsed time, ', 0.004971981048583984)
# Now 129 reached end
# ('elapsed time, ', 0.019487857818603516)
# Now 130 reached end
# ('elapsed time, ', 0.012318134307861328)
# Now 131 reached end
# ('elapsed time, ', 0.011412858963012695)
# Now 132 reached end
# ('elapsed time, ', 0.006552219390869141)
# Now 133 reached end
# ('elapsed time, ', 0.006947994232177734)
# Now 134 reached end
# ('elapsed time, ', 0.02065896987915039)
# Now 135 reached end
# ('elapsed time, ', 0.005527019500732422)
# Now 136 reached end
# ('elapsed time, ', 0.024337053298950195)
# Now 137 reached end
# ('elapsed time, ', 0.0109100341796875)
# Now 138 reached end
# ('elapsed time, ', 0.017300128936767578)
# Now 139 reached end
# ('elapsed time, ', 0.01265096664428711)
# Now 140 reached end
# ('elapsed time, ', 0.00890803337097168)
# Now 141 reached end
# ('elapsed time, ', 0.01754593849182129)
# Now 142 reached end
# ('elapsed time, ', 0.006083965301513672)
# Now 143 reached end
# ('elapsed time, ', 0.0060160160064697266)
# Now 144 reached end
# ('elapsed time, ', 0.010316133499145508)
# Now 145 reached end
# ('elapsed time, ', 0.0073850154876708984)
# Now 146 reached end
# ('elapsed time, ', 0.02903604507446289)
# Now 147 reached end
# ('elapsed time, ', 0.008317947387695312)
# Now 148 reached end
# ('elapsed time, ', 0.0064029693603515625)
# Now 149 reached end
# ('elapsed time, ', 0.011312007904052734)
# Now 150 reached end
# ('elapsed time, ', 0.0071849822998046875)
# Now 151 reached end
# ('elapsed time, ', 0.00439000129699707)
# Now 152 reached end
# ('elapsed time, ', 0.008147001266479492)
# Now 153 reached end
# ('elapsed time, ', 0.007751941680908203)
# Now 154 reached end
# ('elapsed time, ', 0.023555994033813477)
# Now 155 reached end
# ('elapsed time, ', 0.014389991760253906)
# Now 156 reached end
# ('elapsed time, ', 0.015210866928100586)
# Now 157 reached end
# ('elapsed time, ', 0.005259990692138672)
# Now 158 reached end
# ('elapsed time, ', 0.005502939224243164)
# Now 159 reached end
# ('elapsed time, ', 0.0069048404693603516)
# Now 160 reached end
# ('elapsed time, ', 0.018043994903564453)
# Now 161 reached end
# ('elapsed time, ', 0.013554096221923828)
# Now 162 reached end
# ('elapsed time, ', 0.0034110546112060547)
# Now 163 reached end
# ('elapsed time, ', 0.007100105285644531)
# Now 164 reached end
# ('elapsed time, ', 0.005316972732543945)
# Now 165 reached end
# ('elapsed time, ', 0.01532602310180664)
# Now 166 reached end
# ('elapsed time, ', 0.008599996566772461)
# Now 167 reached end
# ('elapsed time, ', 0.007422924041748047)
# Now 168 reached end
# ('elapsed time, ', 0.030686140060424805)
# Now 169 reached end
# ('elapsed time, ', 0.006356000900268555)
# Now 170 reached end
# ('elapsed time, ', 0.003459930419921875)
# Now 171 reached end
# ('elapsed time, ', 0.0069348812103271484)
# Now 172 reached end
# ('elapsed time, ', 0.002196073532104492)
# Now 173 reached end
# ('elapsed time, ', 0.035787105560302734)
# Now 174 reached end
# ('elapsed time, ', 0.004381895065307617)
# Now 175 reached end
# ('elapsed time, ', 0.01081705093383789)
# Now 176 reached end
# ('elapsed time, ', 0.0072479248046875)
# Now 177 reached end
# ('elapsed time, ', 0.004148006439208984)
# Now 178 reached end
# ('elapsed time, ', 0.005223989486694336)
# Now 179 reached end
# ('elapsed time, ', 0.00797891616821289)
# Now 180 reached end
# ('elapsed time, ', 0.015753984451293945)
# Now 181 reached end
# ('elapsed time, ', 0.019260883331298828)
# Now 182 reached end
# ('elapsed time, ', 0.012941837310791016)
# Now 183 reached end
# ('elapsed time, ', 0.013663053512573242)
# Now 184 reached end
# ('elapsed time, ', 0.003938913345336914)
# Now 185 reached end
# ('elapsed time, ', 0.008419990539550781)
# Now 186 reached end
# ('elapsed time, ', 0.01800394058227539)
# Now 187 reached end
# ('elapsed time, ', 0.005132913589477539)
# Now 188 reached end
# ('elapsed time, ', 0.017966032028198242)
# Now 189 reached end
# ('elapsed time, ', 0.007376909255981445)
# Now 190 reached end
# ('elapsed time, ', 0.005579948425292969)
# Now 191 reached end
# ('elapsed time, ', 0.010319948196411133)
# Now 192 reached end
# ('elapsed time, ', 0.005875110626220703)
# Now 193 reached end
# ('elapsed time, ', 0.010384082794189453)
# Now 194 reached end
# ('elapsed time, ', 0.018678903579711914)
# Now 195 reached end
# ('elapsed time, ', 0.013379812240600586)
# Now 196 reached end
# ('elapsed time, ', 0.0061321258544921875)
# Now 197 reached end
# ('elapsed time, ', 0.003217935562133789)
# Now 198 reached end
# ('elapsed time, ', 0.004114866256713867)
# Now 199 reached end
# ('elapsed time, ', 0.006891012191772461)
# Now 200 reached end
# ('elapsed time, ', 0.003962039947509766)
# Now 201 reached end
# ('elapsed time, ', 0.01257014274597168)
# Now 202 reached end
# ('elapsed time, ', 0.006700038909912109)
# Now 203 reached end
# ('elapsed time, ', 0.015480995178222656)
# Now 204 reached end
# ('elapsed time, ', 0.006115913391113281)
# Now 205 reached end
# ('elapsed time, ', 0.005546092987060547)
# Now 206 reached end
# ('elapsed time, ', 0.004017829895019531)
# Now 207 reached end
# ('elapsed time, ', 0.0074579715728759766)
# Now 208 reached end
# ('elapsed time, ', 0.010874032974243164)
# Now 209 reached end
# ('elapsed time, ', 0.00923299789428711)
# Now 210 reached end
# ('elapsed time, ', 0.010864019393920898)
# Now 211 reached end
# ('elapsed time, ', 0.005558013916015625)
# Now 212 reached end
# ('elapsed time, ', 0.0067501068115234375)
# Now 213 reached end
# ('elapsed time, ', 0.0027511119842529297)
# Now 214 reached end
# ('elapsed time, ', 0.011697053909301758)
# Now 215 reached end
# ('elapsed time, ', 0.007714033126831055)
# Now 216 reached end
# ('elapsed time, ', 0.0053539276123046875)
# Now 217 reached end
# ('elapsed time, ', 0.008992910385131836)
# Now 218 reached end
# ('elapsed time, ', 0.005095958709716797)
# Now 219 reached end
# ('elapsed time, ', 0.004029035568237305)
# Now 220 reached end
# ('elapsed time, ', 0.012007951736450195)
# Now 221 reached end
# ('elapsed time, ', 0.012398958206176758)
# Now 222 reached end
# ('elapsed time, ', 0.009479999542236328)
# Now 223 reached end
# ('elapsed time, ', 0.005640983581542969)
# Now 224 reached end
# ('elapsed time, ', 0.01002192497253418)
# Now 225 reached end
# ('elapsed time, ', 0.0038809776306152344)
# Now 226 reached end
# ('elapsed time, ', 0.0028069019317626953)
# Now 227 reached end
# ('elapsed time, ', 0.010102033615112305)
# Now 228 reached end
# ('elapsed time, ', 0.006209135055541992)
# Now 229 reached end
# ('elapsed time, ', 0.005166053771972656)
# Now 230 reached end
# ('elapsed time, ', 0.007375955581665039)
# Now 231 reached end
# ('elapsed time, ', 0.008095026016235352)
# Now 232 reached end
# ('elapsed time, ', 0.004748106002807617)
# Now 233 reached end
# ('elapsed time, ', 0.007441043853759766)
# Now 234 reached end
# ('elapsed time, ', 0.004479169845581055)
# Now 235 reached end
# ('elapsed time, ', 0.002187967300415039)
# Now 236 reached end
# ('elapsed time, ', 0.007483005523681641)
# Now 237 reached end
# ('elapsed time, ', 0.0073430538177490234)
# Now 238 reached end
# ('elapsed time, ', 0.005053997039794922)
# Now 239 reached end
# ('elapsed time, ', 0.01263117790222168)
# Now 240 reached end
# ('elapsed time, ', 0.009672880172729492)
# Now 241 reached end
# ('elapsed time, ', 0.011764049530029297)
# Now 242 reached end
# ('elapsed time, ', 0.015614986419677734)
# Now 243 reached end
# ('elapsed time, ', 0.008549928665161133)
# Now 244 reached end
# ('elapsed time, ', 0.0038089752197265625)
# Now 245 reached end
# ('elapsed time, ', 0.009888887405395508)
# Now 246 reached end
# ('elapsed time, ', 0.012958049774169922)
# Now 247 reached end
# ('elapsed time, ', 0.017554044723510742)
# Now 248 reached end
# ('elapsed time, ', 0.012068033218383789)
# Now 249 reached end
# ('elapsed time, ', 0.004776954650878906)
# Now 250 reached end
# ('elapsed time, ', 0.012984991073608398)
# Now 251 reached end
# ('elapsed time, ', 0.009886980056762695)
# Now 252 reached end
# ('elapsed time, ', 0.006051063537597656)
# Now 253 reached end
# ('elapsed time, ', 0.0035390853881835938)
# Now 254 reached end
# ('elapsed time, ', 0.012866973876953125)
# Now 255 reached end
# ('elapsed time, ', 0.004836082458496094)
# Now 256 reached end
# ('elapsed time, ', 0.012881994247436523)
# Now 257 reached end
# ('elapsed time, ', 0.00409388542175293)
# Now 258 reached end
# ('elapsed time, ', 0.0041561126708984375)
# Now 259 reached end
# ('elapsed time, ', 0.006758928298950195)
# Now 260 reached end
# ('elapsed time, ', 0.014373064041137695)
# Now 261 reached end
# ('elapsed time, ', 0.009155988693237305)
# Now 262 reached end
# ('elapsed time, ', 0.013196945190429688)
# Now 263 reached end
# ('elapsed time, ', 0.021636009216308594)
# Now 264 reached end
# ('elapsed time, ', 0.008719921112060547)
# Now 265 reached end
# ('elapsed time, ', 0.008253097534179688)
# Now 266 reached end
# ('elapsed time, ', 0.007729053497314453)
# Now 267 reached end
# ('elapsed time, ', 0.004389047622680664)
# Now 268 reached end
# ('elapsed time, ', 0.011364936828613281)
# Now 269 reached end
# ('elapsed time, ', 0.009487152099609375)
# Now 270 reached end
# ('elapsed time, ', 0.01220393180847168)
# Now 271 reached end
# ('elapsed time, ', 0.0054759979248046875)
# Now 272 reached end
# ('elapsed time, ', 0.0052471160888671875)
# Now 273 reached end
# ('elapsed time, ', 0.0058650970458984375)
# Now 274 reached end
# ('elapsed time, ', 0.0041730403900146484)
# Now 275 reached end
# ('elapsed time, ', 0.007959127426147461)
# Now 276 reached end
# ('elapsed time, ', 0.0071909427642822266)
# Now 277 reached end
# ('elapsed time, ', 0.007688999176025391)
# Now 278 reached end
# ('elapsed time, ', 0.005438089370727539)
# Now 279 reached end
# ('elapsed time, ', 0.005135774612426758)
# Now 280 reached end
# ('elapsed time, ', 0.016062021255493164)
# Now 281 reached end
# ('elapsed time, ', 0.008102893829345703)
# Now 282 reached end
# ('elapsed time, ', 0.007940053939819336)
# Now 283 reached end
# ('elapsed time, ', 0.013082027435302734)
# Now 284 reached end
# ('elapsed time, ', 0.010651111602783203)
# Now 285 reached end
# ('elapsed time, ', 0.010465145111083984)
# Now 286 reached end
# ('elapsed time, ', 0.008911848068237305)
# Now 287 reached end
# ('elapsed time, ', 0.003515005111694336)
# Now 288 reached end
# ('elapsed time, ', 0.008669137954711914)
# Now 289 reached end
# ('elapsed time, ', 0.006218910217285156)
# Now 290 reached end
# ('elapsed time, ', 0.0062329769134521484)
# Now 291 reached end
# ('elapsed time, ', 0.010775089263916016)
# Now 292 reached end
# ('elapsed time, ', 0.009378910064697266)
# Now 293 reached end
# ('elapsed time, ', 0.0053310394287109375)
# Now 294 reached end
# ('elapsed time, ', 0.004802227020263672)
# Now 295 reached end
# ('elapsed time, ', 0.011945009231567383)
# Now 296 reached end
# ('elapsed time, ', 0.016653776168823242)
# Now 297 reached end
# ('elapsed time, ', 0.008774042129516602)
# Now 298 reached end
# ('elapsed time, ', 0.005948066711425781)
# Now 299 reached end
# ('elapsed time, ', 0.006883859634399414)
# Now 300 reached end
# ('elapsed time, ', 0.006092071533203125)
# Now 301 reached end
# ('elapsed time, ', 0.0025398731231689453)
# Now 302 reached end
# ('elapsed time, ', 0.003126859664916992)
# Now 303 reached end
# ('elapsed time, ', 0.003262042999267578)
# Now 304 reached end
# ('elapsed time, ', 0.002123117446899414)
# Now 305 reached end
# ('elapsed time, ', 0.008780956268310547)
# Now 306 reached end
# ('elapsed time, ', 0.008989810943603516)
# Now 307 reached end
# ('elapsed time, ', 0.005143880844116211)
# Now 308 reached end
# ('elapsed time, ', 0.004796028137207031)
# Now 309 reached end
# ('elapsed time, ', 0.010761022567749023)
# Now 310 reached end
# ('elapsed time, ', 0.0027189254760742188)
# Now 311 reached end
# ('elapsed time, ', 0.012280941009521484)
# Now 312 reached end
# ('elapsed time, ', 0.018867969512939453)
# Now 313 reached end
# ('elapsed time, ', 0.004624128341674805)
# Now 314 reached end
# ('elapsed time, ', 0.006198883056640625)
# Now 315 reached end
# ('elapsed time, ', 0.005217075347900391)
# Now 316 reached end
# ('elapsed time, ', 0.01228022575378418)
# Now 317 reached end
# ('elapsed time, ', 0.006662130355834961)
# Now 318 reached end
# ('elapsed time, ', 0.0065000057220458984)
# Now 319 reached end
# ('elapsed time, ', 0.008666038513183594)
# Now 320 reached end
# ('elapsed time, ', 0.01285696029663086)
# Now 321 reached end
# ('elapsed time, ', 0.0036199092864990234)
# Now 322 reached end
# ('elapsed time, ', 0.009114980697631836)
# Now 323 reached end
# ('elapsed time, ', 0.008536815643310547)
# Now 324 reached end
# ('elapsed time, ', 0.006405830383300781)
# Now 325 reached end
# ('elapsed time, ', 0.010110855102539062)
# Now 326 reached end
# ('elapsed time, ', 0.002627849578857422)
# Now 327 reached end
# ('elapsed time, ', 0.008825063705444336)
# Now 328 reached end
# ('elapsed time, ', 0.0057828426361083984)
# Now 329 reached end
# ('elapsed time, ', 0.006392955780029297)
# Now 330 reached end
# ('elapsed time, ', 0.0034720897674560547)
# Now 331 reached end
# ('elapsed time, ', 0.0032961368560791016)
# Now 332 reached end
# ('elapsed time, ', 0.0066471099853515625)
# Now 333 reached end
# ('elapsed time, ', 0.00698399543762207)
# Now 334 reached end
# ('elapsed time, ', 0.0034580230712890625)
# Now 335 reached end
# ('elapsed time, ', 0.009701967239379883)
# Now 336 reached end
# ('elapsed time, ', 0.003906965255737305)
# Now 337 reached end
# ('elapsed time, ', 0.005059957504272461)
# Now 338 reached end
# ('elapsed time, ', 0.010926961898803711)
# Now 339 reached end
# ('elapsed time, ', 0.0019228458404541016)
# Now 340 reached end
# ('elapsed time, ', 0.005471944808959961)
# Now 341 reached end
# ('elapsed time, ', 0.004022121429443359)
# Now 342 reached end
# ('elapsed time, ', 0.004712104797363281)
# Now 343 reached end
# ('elapsed time, ', 0.004695892333984375)
# Now 344 reached end
# ('elapsed time, ', 0.0053250789642333984)
# Now 345 reached end
# ('elapsed time, ', 0.008919954299926758)
# Now 346 reached end
# ('elapsed time, ', 0.0037081241607666016)
# Now 347 reached end
# ('elapsed time, ', 0.0023958683013916016)
# Now 348 reached end
# ('elapsed time, ', 0.010271072387695312)
# Now 349 reached end
# ('elapsed time, ', 0.006818056106567383)
# Now 350 reached end
# ('elapsed time, ', 0.015633106231689453)
# Now 351 reached end
# ('elapsed time, ', 0.01668405532836914)
# Now 352 reached end
# ('elapsed time, ', 0.007166862487792969)
# Now 353 reached end
# ('elapsed time, ', 0.010818004608154297)
# Now 354 reached end
# ('elapsed time, ', 0.014742851257324219)
# Now 355 reached end
# ('elapsed time, ', 0.013252019882202148)
# Now 356 reached end
# ('elapsed time, ', 0.00632786750793457)
# Now 357 reached end
# ('elapsed time, ', 0.003984928131103516)
# Now 358 reached end
# ('elapsed time, ', 0.005795955657958984)
# Now 359 reached end
# ('elapsed time, ', 0.0025701522827148438)
# Now 360 reached end
# ('elapsed time, ', 0.0055389404296875)
# Now 361 reached end
# ('elapsed time, ', 0.0030879974365234375)
# Now 362 reached end
# ('elapsed time, ', 0.002228975296020508)
# Now 363 reached end
# ('elapsed time, ', 0.002643108367919922)
# Now 364 reached end
# ('elapsed time, ', 0.002766132354736328)
# Now 365 reached end
# ('elapsed time, ', 0.002149820327758789)
# Now 366 reached end
# ('elapsed time, ', 0.0055999755859375)
# Now 367 reached end
# ('elapsed time, ', 0.01005101203918457)
# Now 368 reached end
# ('elapsed time, ', 0.009578943252563477)
# Now 369 reached end
# ('elapsed time, ', 0.006974220275878906)
# Now 370 reached end
# ('elapsed time, ', 0.011139869689941406)
# Now 371 reached end
# ('elapsed time, ', 0.0064771175384521484)
# Now 372 reached end
# ('elapsed time, ', 0.0227968692779541)
# Now 373 reached end
# ('elapsed time, ', 0.006527900695800781)
# Now 374 reached end
# ('elapsed time, ', 0.015486955642700195)
# Now 375 reached end
# ('elapsed time, ', 0.0063359737396240234)
# Now 376 reached end
# ('elapsed time, ', 0.004393100738525391)
# Now 377 reached end
# ('elapsed time, ', 0.004518985748291016)
# Now 378 reached end
# ('elapsed time, ', 0.009282112121582031)
# Now 379 reached end
# ('elapsed time, ', 0.00419306755065918)
# Now 380 reached end
# ('elapsed time, ', 0.003549814224243164)
# Now 381 reached end
# ('elapsed time, ', 0.011487960815429688)
# Now 382 reached end
# ('elapsed time, ', 0.0033910274505615234)
# Now 383 reached end
# ('elapsed time, ', 0.005958080291748047)
# Now 384 reached end
# ('elapsed time, ', 0.00803995132446289)
# Now 385 reached end
# ('elapsed time, ', 0.0034749507904052734)
# Now 386 reached end
# ('elapsed time, ', 0.005239963531494141)
# Now 387 reached end
# ('elapsed time, ', 0.00576019287109375)
# Now 388 reached end
# ('elapsed time, ', 0.008799076080322266)
# Now 389 reached end
# ('elapsed time, ', 0.004818916320800781)
# Now 390 reached end
# ('elapsed time, ', 0.0016009807586669922)
# Now 391 reached end
# ('elapsed time, ', 0.004010915756225586)
# Now 392 reached end
# ('elapsed time, ', 0.003020048141479492)
# Now 393 reached end
# ('elapsed time, ', 0.0025529861450195312)
# Now 394 reached end
# ('elapsed time, ', 0.009387969970703125)
# Now 395 reached end
# ('elapsed time, ', 0.017155170440673828)
# Now 396 reached end
# ('elapsed time, ', 0.009783029556274414)
# Now 397 reached end
# ('elapsed time, ', 0.006559133529663086)
# Now 398 reached end
# ('elapsed time, ', 0.015871047973632812)
# Now 399 reached end
# ('elapsed time, ', 0.029536962509155273)
# Now 400 reached end
# ('elapsed time, ', 0.004702091217041016)
# Now 401 reached end
# ('elapsed time, ', 0.018878936767578125)
# Now 402 reached end
# ('elapsed time, ', 0.0026619434356689453)
# Now 403 reached end
# ('elapsed time, ', 0.005781888961791992)
# Now 404 reached end
# ('elapsed time, ', 0.011960029602050781)
# Now 405 reached end
# ('elapsed time, ', 0.002691030502319336)
# Now 406 reached end
# ('elapsed time, ', 0.0022919178009033203)
# Now 407 reached end
# ('elapsed time, ', 0.00988006591796875)
# Now 408 reached end
# ('elapsed time, ', 0.0018758773803710938)
# Now 409 reached end
# ('elapsed time, ', 0.006986856460571289)
# Now 410 reached end
# ('elapsed time, ', 0.004589080810546875)
# Now 411 reached end
# ('elapsed time, ', 0.006166934967041016)
# Now 412 reached end
# ('elapsed time, ', 0.00568699836730957)
# Now 413 reached end
# ('elapsed time, ', 0.0050241947174072266)
# Now 414 reached end
# ('elapsed time, ', 0.015998125076293945)
# Now 415 reached end
# ('elapsed time, ', 0.003918170928955078)
# Now 416 reached end
# ('elapsed time, ', 0.008917093276977539)
# Now 417 reached end
# ('elapsed time, ', 0.0036249160766601562)
# Now 418 reached end
# ('elapsed time, ', 0.00857400894165039)
# Now 419 reached end
# ('elapsed time, ', 0.007506132125854492)
# Now 420 reached end
# ('elapsed time, ', 0.007924079895019531)
# Now 421 reached end
# ('elapsed time, ', 0.004837989807128906)
# Now 422 reached end
# ('elapsed time, ', 0.0042819976806640625)
# Now 423 reached end
# ('elapsed time, ', 0.0054018497467041016)
# Now 424 reached end
# ('elapsed time, ', 0.004135847091674805)
# Now 425 reached end
# ('elapsed time, ', 0.004792213439941406)
# Now 426 reached end
# ('elapsed time, ', 0.006289005279541016)
# Now 427 reached end
# ('elapsed time, ', 0.012701034545898438)
# Now 428 reached end
# ('elapsed time, ', 0.0021491050720214844)
# Now 429 reached end
# ('elapsed time, ', 0.004062175750732422)
# Now 430 reached end
# ('elapsed time, ', 0.004452943801879883)
# Now 431 reached end
# ('elapsed time, ', 0.003175020217895508)
# Now 432 reached end
# ('elapsed time, ', 0.0037980079650878906)
# Now 433 reached end
# ('elapsed time, ', 0.023229122161865234)
# Now 434 reached end
# ('elapsed time, ', 0.009730100631713867)
# Now 435 reached end
# ('elapsed time, ', 0.005410909652709961)
# Now 436 reached end
# ('elapsed time, ', 0.00820612907409668)
# Now 437 reached end
# ('elapsed time, ', 0.003512859344482422)
# Now 438 reached end
# ('elapsed time, ', 0.005254030227661133)
# Now 439 reached end
# ('elapsed time, ', 0.006587028503417969)
# Now 440 reached end
# ('elapsed time, ', 0.0038640499114990234)
# Now 441 reached end
# ('elapsed time, ', 0.0035119056701660156)
# Now 442 reached end
# ('elapsed time, ', 0.01063990592956543)
# Now 443 reached end
# ('elapsed time, ', 0.0017938613891601562)
# Now 444 reached end
# ('elapsed time, ', 0.008108854293823242)
# Now 445 reached end
# ('elapsed time, ', 0.008305072784423828)
# Now 446 reached end
# ('elapsed time, ', 0.004515171051025391)
# Now 447 reached end
# ('elapsed time, ', 0.0021140575408935547)
# Now 448 reached end
# ('elapsed time, ', 0.004922151565551758)
# Now 449 reached end
# ('elapsed time, ', 0.008701086044311523)
# Now 450 reached end
# ('elapsed time, ', 0.005354166030883789)
# Now 451 reached end
# ('elapsed time, ', 0.0048639774322509766)
# Now 452 reached end
# ('elapsed time, ', 0.001638174057006836)
# Now 453 reached end
# ('elapsed time, ', 0.008302927017211914)
# Now 454 reached end
# ('elapsed time, ', 0.010447978973388672)
# Now 455 reached end
# ('elapsed time, ', 0.011963129043579102)
# Now 456 reached end
# ('elapsed time, ', 0.0063169002532958984)
# Now 457 reached end
# ('elapsed time, ', 0.0028150081634521484)
# Now 458 reached end
# ('elapsed time, ', 0.0099029541015625)
# Now 459 reached end
# ('elapsed time, ', 0.029909133911132812)
# Now 460 reached end
# ('elapsed time, ', 0.004878044128417969)
# Now 461 reached end
# ('elapsed time, ', 0.0074329376220703125)
# Now 462 reached end
# ('elapsed time, ', 0.005110025405883789)
# Now 463 reached end
# ('elapsed time, ', 0.01030278205871582)
# Now 464 reached end
# ('elapsed time, ', 0.008598089218139648)
# Now 465 reached end
# ('elapsed time, ', 0.0060079097747802734)
# Now 466 reached end
# ('elapsed time, ', 0.004175901412963867)
# Now 467 reached end
# ('elapsed time, ', 0.008891105651855469)
# Now 468 reached end
# ('elapsed time, ', 0.003506898880004883)
# Now 469 reached end
# ('elapsed time, ', 0.004049062728881836)
# Now 470 reached end
# ('elapsed time, ', 0.009339094161987305)
# Now 471 reached end
# ('elapsed time, ', 0.007128000259399414)
# Now 472 reached end
# ('elapsed time, ', 0.008624076843261719)
# Now 473 reached end
# ('elapsed time, ', 0.00598907470703125)
# Now 474 reached end
# ('elapsed time, ', 0.009010076522827148)
# Now 475 reached end
# ('elapsed time, ', 0.008611917495727539)
# Now 476 reached end
# ('elapsed time, ', 0.013927936553955078)
# Now 477 reached end
# ('elapsed time, ', 0.004761934280395508)
# Now 478 reached end
# ('elapsed time, ', 0.0057218074798583984)
# Now 479 reached end
# ('elapsed time, ', 0.011681079864501953)
# Now 480 reached end
# ('elapsed time, ', 0.008980989456176758)
# Now 481 reached end
# ('elapsed time, ', 0.006185054779052734)
# Now 482 reached end
# ('elapsed time, ', 0.0031909942626953125)
# Now 483 reached end
# ('elapsed time, ', 0.005496025085449219)
# Now 484 reached end
# ('elapsed time, ', 0.007234811782836914)
# Now 485 reached end
# ('elapsed time, ', 0.004976987838745117)
# Now 486 reached end
# ('elapsed time, ', 0.007629871368408203)
# Now 487 reached end
# ('elapsed time, ', 0.008983135223388672)
# Now 488 reached end
# ('elapsed time, ', 0.006202220916748047)
# Now 489 reached end
# ('elapsed time, ', 0.007925987243652344)
# Now 490 reached end
# ('elapsed time, ', 0.008840084075927734)
# Now 491 reached end
# ('elapsed time, ', 0.003593921661376953)
# Now 492 reached end
# ('elapsed time, ', 0.019257068634033203)
# Now 493 reached end
# ('elapsed time, ', 0.006406068801879883)
# Now 494 reached end
# ('elapsed time, ', 0.0032410621643066406)
# Now 495 reached end
# ('elapsed time, ', 0.0043659210205078125)
# Now 496 reached end
# ('elapsed time, ', 0.004709005355834961)
# Now 497 reached end
# ('elapsed time, ', 0.009160995483398438)
# Now 498 reached end
# ('elapsed time, ', 0.006002902984619141)
# Now 499 reached end
# ('elapsed time, ', 0.0064470767974853516)
# Now 500 reached end
# ('elapsed time, ', 0.007231950759887695)
# Now 501 reached end
# ('elapsed time, ', 0.004085063934326172)
# Now 502 reached end
# ('elapsed time, ', 0.010687828063964844)
# Now 503 reached end
# ('elapsed time, ', 0.0037081241607666016)
# Now 504 reached end
# ('elapsed time, ', 0.0016779899597167969)
# Now 505 reached end
# ('elapsed time, ', 0.010577917098999023)
# Now 506 reached end
# ('elapsed time, ', 0.0033159255981445312)
# Now 507 reached end
# ('elapsed time, ', 0.005088090896606445)
# Now 508 reached end
# ('elapsed time, ', 0.0018329620361328125)
# Now 509 reached end
# ('elapsed time, ', 0.0059010982513427734)
# Now 510 reached end
# ('elapsed time, ', 0.004935026168823242)
# Now 511 reached end
# ('elapsed time, ', 0.0035970211029052734)
# Now 512 reached end
# ('elapsed time, ', 0.009012937545776367)
# Now 513 reached end
# ('elapsed time, ', 0.0057830810546875)
# Now 514 reached end
# ('elapsed time, ', 0.00286102294921875)
# Now 515 reached end
# ('elapsed time, ', 0.005319833755493164)
# Now 516 reached end
# ('elapsed time, ', 0.006245136260986328)
# Now 517 reached end
# ('elapsed time, ', 0.008083105087280273)
# Now 518 reached end
# ('elapsed time, ', 0.0021131038665771484)
# Now 519 reached end
# ('elapsed time, ', 0.006527900695800781)
# Now 520 reached end
# ('elapsed time, ', 0.003674030303955078)
# Now 521 reached end
# ('elapsed time, ', 0.003042936325073242)
# Now 522 reached end
# ('elapsed time, ', 0.006242990493774414)
# Now 523 reached end
# ('elapsed time, ', 0.005311012268066406)
# Now 524 reached end
# ('elapsed time, ', 0.008169889450073242)
# Now 525 reached end
# ('elapsed time, ', 0.006536006927490234)
# Now 526 reached end
# ('elapsed time, ', 0.009368181228637695)
# Now 527 reached end
# ('elapsed time, ', 0.005846977233886719)
# Now 528 reached end
# ('elapsed time, ', 0.0066678524017333984)
# Now 529 reached end
# ('elapsed time, ', 0.01158595085144043)
# Now 530 reached end
# ('elapsed time, ', 0.009155035018920898)
# Now 531 reached end
# ('elapsed time, ', 0.008578062057495117)
# Now 532 reached end
# ('elapsed time, ', 0.0029900074005126953)
# Now 533 reached end
# ('elapsed time, ', 0.0031080245971679688)
# Now 534 reached end
# ('elapsed time, ', 0.005486011505126953)
# Now 535 reached end
# ('elapsed time, ', 0.008410930633544922)
# Now 536 reached end
# ('elapsed time, ', 0.0035691261291503906)
# Now 537 reached end
# ('elapsed time, ', 0.00752711296081543)
# Now 538 reached end
# ('elapsed time, ', 0.0036242008209228516)
# Now 539 reached end
# ('elapsed time, ', 0.007122039794921875)
# Now 540 reached end
# ('elapsed time, ', 0.003934144973754883)
# Now 541 reached end
# ('elapsed time, ', 0.009176015853881836)
# Now 542 reached end
# ('elapsed time, ', 0.004106998443603516)
# Now 543 reached end
# ('elapsed time, ', 0.006818056106567383)
# Now 544 reached end
# ('elapsed time, ', 0.005062103271484375)
# Now 545 reached end
# ('elapsed time, ', 0.004652976989746094)
# Now 546 reached end
# ('elapsed time, ', 0.003367900848388672)
# Now 547 reached end
# ('elapsed time, ', 0.012228012084960938)
# Now 548 reached end
# ('elapsed time, ', 0.005117893218994141)
# Now 549 reached end
# ('elapsed time, ', 0.0049250125885009766)
# Now 550 reached end
# ('elapsed time, ', 0.013588190078735352)
# Now 551 reached end
# ('elapsed time, ', 0.026947021484375)
# Now 552 reached end
# ('elapsed time, ', 0.007843971252441406)
# Now 553 reached end
# ('elapsed time, ', 0.0037491321563720703)
# Now 554 reached end
# ('elapsed time, ', 0.006399869918823242)
# Now 555 reached end
# ('elapsed time, ', 0.008597850799560547)
# Now 556 reached end
# ('elapsed time, ', 0.008925914764404297)
# Now 557 reached end
# ('elapsed time, ', 0.005670070648193359)
# Now 558 reached end
# ('elapsed time, ', 0.01070094108581543)
# Now 559 reached end
# ('elapsed time, ', 0.0077669620513916016)
# Now 560 reached end
# ('elapsed time, ', 0.007079124450683594)
# Now 561 reached end
# ('elapsed time, ', 0.006114959716796875)
# Now 562 reached end
# ('elapsed time, ', 0.025695085525512695)
# Now 563 reached end
# ('elapsed time, ', 0.006934165954589844)
# Now 564 reached end
# ('elapsed time, ', 0.001856088638305664)
# Now 565 reached end
# ('elapsed time, ', 0.00472712516784668)
# Now 566 reached end
# ('elapsed time, ', 0.0078029632568359375)
# Now 567 reached end
# ('elapsed time, ', 0.005612850189208984)
# Now 568 reached end
# ('elapsed time, ', 0.004890918731689453)
# Now 569 reached end
# ('elapsed time, ', 0.008306026458740234)
# Now 570 reached end
# ('elapsed time, ', 0.003219127655029297)
# Now 571 reached end
# ('elapsed time, ', 0.005851030349731445)
# Now 572 reached end
# ('elapsed time, ', 0.006913900375366211)
# Now 573 reached end
# ('elapsed time, ', 0.00857996940612793)
# Now 574 reached end
# ('elapsed time, ', 0.009099960327148438)
# Now 575 reached end
# ('elapsed time, ', 0.014279842376708984)
# Now 576 reached end
# ('elapsed time, ', 0.00616002082824707)
# Now 577 reached end
# ('elapsed time, ', 0.0022580623626708984)
# Now 578 reached end
# ('elapsed time, ', 0.0048940181732177734)
# Now 579 reached end
# ('elapsed time, ', 0.004578113555908203)
# Now 580 reached end
# ('elapsed time, ', 0.007849931716918945)
# Now 581 reached end
# ('elapsed time, ', 0.014256000518798828)
# Now 582 reached end
# ('elapsed time, ', 0.003423929214477539)
# Now 583 reached end
# ('elapsed time, ', 0.004090070724487305)
# Now 584 reached end
# ('elapsed time, ', 0.010535001754760742)
# Now 585 reached end
# ('elapsed time, ', 0.012698888778686523)
# Now 586 reached end
# ('elapsed time, ', 0.0025529861450195312)
# Now 587 reached end
# ('elapsed time, ', 0.004286050796508789)
# Now 588 reached end
# ('elapsed time, ', 0.005962848663330078)
# Now 589 reached end
# ('elapsed time, ', 0.005901813507080078)
# Now 590 reached end
# ('elapsed time, ', 0.00577092170715332)
# Now 591 reached end
# ('elapsed time, ', 0.01026010513305664)
# Now 592 reached end
# ('elapsed time, ', 0.015976905822753906)
# Now 593 reached end
# ('elapsed time, ', 0.005628108978271484)
# Now 594 reached end
# ('elapsed time, ', 0.005433082580566406)
# Now 595 reached end
# ('elapsed time, ', 0.005937099456787109)
# Now 596 reached end
# ('elapsed time, ', 0.011285066604614258)
# Now 597 reached end
# ('elapsed time, ', 0.0024688243865966797)
# Now 598 reached end
# ('elapsed time, ', 0.004065990447998047)
# Now 599 reached end
# ('elapsed time, ', 0.005589008331298828)
# Now 600 reached end
# ('elapsed time, ', 0.010891914367675781)
# Now 601 reached end
# ('elapsed time, ', 0.005918979644775391)
# Now 602 reached end
# ('elapsed time, ', 0.01084589958190918)
# Now 603 reached end
# ('elapsed time, ', 0.006471872329711914)
# Now 604 reached end
# ('elapsed time, ', 0.008190155029296875)
# Now 605 reached end
# ('elapsed time, ', 0.013200998306274414)
# Now 606 reached end
# ('elapsed time, ', 0.004754781723022461)
# Now 607 reached end
# ('elapsed time, ', 0.005054950714111328)
# Now 608 reached end
# ('elapsed time, ', 0.003751039505004883)
# Now 609 reached end
# ('elapsed time, ', 0.008962869644165039)
# Now 610 reached end
# ('elapsed time, ', 0.010746955871582031)
# Now 611 reached end
# ('elapsed time, ', 0.004094839096069336)
# Now 612 reached end
# ('elapsed time, ', 0.0054018497467041016)
# Now 613 reached end
# ('elapsed time, ', 0.007602214813232422)
# Now 614 reached end
# ('elapsed time, ', 0.003036975860595703)
# Now 615 reached end
# ('elapsed time, ', 0.0035271644592285156)
# Now 616 reached end
# ('elapsed time, ', 0.015060186386108398)
# Now 617 reached end
# ('elapsed time, ', 0.0055391788482666016)
# Now 618 reached end
# ('elapsed time, ', 0.007676839828491211)
# Now 619 reached end
# ('elapsed time, ', 0.004086971282958984)
# Now 620 reached end
# ('elapsed time, ', 0.0037469863891601562)
# Now 621 reached end
# ('elapsed time, ', 0.0035359859466552734)
# Now 622 reached end
# ('elapsed time, ', 0.011330127716064453)
# Now 623 reached end
# ('elapsed time, ', 0.008357048034667969)
# Now 624 reached end
# ('elapsed time, ', 0.0264589786529541)
# Now 625 reached end
# ('elapsed time, ', 0.005386829376220703)
# Now 626 reached end
# ('elapsed time, ', 0.015188217163085938)
# Now 627 reached end
# ('elapsed time, ', 0.0032720565795898438)
# Now 628 reached end
# ('elapsed time, ', 0.003314971923828125)
# Now 629 reached end
# ('elapsed time, ', 0.014456987380981445)
# Now 630 reached end
# ('elapsed time, ', 0.007055997848510742)
# Now 631 reached end
# ('elapsed time, ', 0.0044591426849365234)
# Now 632 reached end
# ('elapsed time, ', 0.0020029544830322266)
# Now 633 reached end
# ('elapsed time, ', 0.008329153060913086)
# Now 634 reached end
# ('elapsed time, ', 0.001355886459350586)
# Now 635 reached end
# ('elapsed time, ', 0.014431953430175781)
# Now 636 reached end
# ('elapsed time, ', 0.007239103317260742)
# Now 637 reached end
# ('elapsed time, ', 0.0044748783111572266)
# Now 638 reached end
# ('elapsed time, ', 0.01575493812561035)
# Now 639 reached end
# ('elapsed time, ', 0.008989095687866211)
# Now 640 reached end
# ('elapsed time, ', 0.015127897262573242)
# Now 641 reached end
# ('elapsed time, ', 0.002357006072998047)
# Now 642 reached end
# ('elapsed time, ', 0.009882926940917969)
# Now 643 reached end
# ('elapsed time, ', 0.0026590824127197266)
# Now 644 reached end
# ('elapsed time, ', 0.004454851150512695)
# Now 645 reached end
# ('elapsed time, ', 0.002894878387451172)
# Now 646 reached end
# ('elapsed time, ', 0.003654003143310547)
# Now 647 reached end
# ('elapsed time, ', 0.010547876358032227)
# Now 648 reached end
# ('elapsed time, ', 0.0028650760650634766)
# Now 649 reached end
# ('elapsed time, ', 0.0032150745391845703)
# Now 650 reached end
# ('elapsed time, ', 0.005402088165283203)
# Now 651 reached end
# ('elapsed time, ', 0.0072062015533447266)
# Now 652 reached end
# ('elapsed time, ', 0.010352849960327148)
# Now 653 reached end
# ('elapsed time, ', 0.008606910705566406)
# Now 654 reached end
# ('elapsed time, ', 0.006867885589599609)
# Now 655 reached end
# ('elapsed time, ', 0.011492013931274414)
# Now 656 reached end
# ('elapsed time, ', 0.007266998291015625)
# Now 657 reached end
# ('elapsed time, ', 0.005187034606933594)
# Now 658 reached end
# ('elapsed time, ', 0.01370096206665039)
# Now 659 reached end
# ('elapsed time, ', 0.01506805419921875)
# Now 660 reached end
# ('elapsed time, ', 0.0033309459686279297)
# Now 661 reached end
# ('elapsed time, ', 0.0048100948333740234)
# Now 662 reached end
# ('elapsed time, ', 0.006540060043334961)
# Now 663 reached end
# ('elapsed time, ', 0.011232852935791016)
# Now 664 reached end
# ('elapsed time, ', 0.009778022766113281)
# Now 665 reached end
# ('elapsed time, ', 0.005763053894042969)
# Now 666 reached end
# ('elapsed time, ', 0.004369020462036133)
# Now 667 reached end
# ('elapsed time, ', 0.005028963088989258)
# Now 668 reached end
# ('elapsed time, ', 0.017773866653442383)
# Now 669 reached end
# ('elapsed time, ', 0.0035347938537597656)
# Now 670 reached end
# ('elapsed time, ', 0.007554054260253906)
# Now 671 reached end
# ('elapsed time, ', 0.005925178527832031)
# Now 672 reached end
# ('elapsed time, ', 0.01053619384765625)
# Now 673 reached end
# ('elapsed time, ', 0.017292022705078125)
# Now 674 reached end
# ('elapsed time, ', 0.012202978134155273)
# Now 675 reached end
# ('elapsed time, ', 0.009025096893310547)
# Now 676 reached end
# ('elapsed time, ', 0.004950046539306641)
# Now 677 reached end
# ('elapsed time, ', 0.01666712760925293)
# Now 678 reached end
# ('elapsed time, ', 0.009608030319213867)
# Now 679 reached end
# ('elapsed time, ', 0.008239030838012695)
# Now 680 reached end
# ('elapsed time, ', 0.004992961883544922)
# Now 681 reached end
# ('elapsed time, ', 0.0027120113372802734)
# Now 682 reached end
# ('elapsed time, ', 0.0050580501556396484)
# Now 683 reached end
# ('elapsed time, ', 0.006108999252319336)
# Now 684 reached end
# ('elapsed time, ', 0.017154932022094727)
# Now 685 reached end
# ('elapsed time, ', 0.0034508705139160156)
# Now 686 reached end
# ('elapsed time, ', 0.01086282730102539)
# Now 687 reached end
# ('elapsed time, ', 0.005163908004760742)
# Now 688 reached end
# ('elapsed time, ', 0.016230106353759766)
# Now 689 reached end
# ('elapsed time, ', 0.003869771957397461)
# Now 690 reached end
# ('elapsed time, ', 0.003442049026489258)
# Now 691 reached end
# ('elapsed time, ', 0.006278038024902344)
# Now 692 reached end
# ('elapsed time, ', 0.0054700374603271484)
# Now 693 reached end
# ('elapsed time, ', 0.0030760765075683594)
# Now 694 reached end
# ('elapsed time, ', 0.005174160003662109)
# Now 695 reached end
# ('elapsed time, ', 0.0036520957946777344)
# Now 696 reached end
# ('elapsed time, ', 0.009591817855834961)
# Now 697 reached end
# ('elapsed time, ', 0.007154941558837891)
# Now 698 reached end
# ('elapsed time, ', 0.003072023391723633)
# Now 699 reached end
# ('elapsed time, ', 0.009044885635375977)
# Now 700 reached end
# ('elapsed time, ', 0.007825136184692383)
# Now 701 reached end
# ('elapsed time, ', 0.00722813606262207)
# Now 702 reached end
# ('elapsed time, ', 0.010513067245483398)
# Now 703 reached end
# ('elapsed time, ', 0.011141061782836914)
# Now 704 reached end
# ('elapsed time, ', 0.008147001266479492)
# Now 705 reached end
# ('elapsed time, ', 0.0073909759521484375)
# Now 706 reached end
# ('elapsed time, ', 0.010478019714355469)
# Now 707 reached end
# ('elapsed time, ', 0.019418001174926758)
# Now 708 reached end
# ('elapsed time, ', 0.004228115081787109)
# Now 709 reached end
# ('elapsed time, ', 0.00906682014465332)
# Now 710 reached end
# ('elapsed time, ', 0.012051105499267578)
# Now 711 reached end
# ('elapsed time, ', 0.00415492057800293)
# Now 712 reached end
# ('elapsed time, ', 0.013262033462524414)
# Now 713 reached end
# ('elapsed time, ', 0.003431081771850586)
# Now 714 reached end
# ('elapsed time, ', 0.00542902946472168)
# Now 715 reached end
# ('elapsed time, ', 0.006922006607055664)
# Now 716 reached end
# ('elapsed time, ', 0.007411956787109375)
# Now 717 reached end
# ('elapsed time, ', 0.010003805160522461)
# Now 718 reached end
# ('elapsed time, ', 0.0033998489379882812)
# Now 719 reached end
# ('elapsed time, ', 0.006735086441040039)
# Now 720 reached end
# ('elapsed time, ', 0.0040130615234375)
# Now 721 reached end
# ('elapsed time, ', 0.00905299186706543)
# Now 722 reached end
# ('elapsed time, ', 0.004201173782348633)
# Now 723 reached end
# ('elapsed time, ', 0.011696100234985352)
# Now 724 reached end
# ('elapsed time, ', 0.007174968719482422)
# Now 725 reached end
# ('elapsed time, ', 0.0067958831787109375)
# Now 726 reached end
# ('elapsed time, ', 0.00403904914855957)
# Now 727 reached end
# ('elapsed time, ', 0.0024759769439697266)
# Now 728 reached end
# ('elapsed time, ', 0.006276845932006836)
# Now 729 reached end
# ('elapsed time, ', 0.006282806396484375)
# Now 730 reached end
# ('elapsed time, ', 0.0074079036712646484)
# Now 731 reached end
# ('elapsed time, ', 0.005604982376098633)
# Now 732 reached end
# ('elapsed time, ', 0.009356021881103516)
# Now 733 reached end
# ('elapsed time, ', 0.00953984260559082)
# Now 734 reached end
# ('elapsed time, ', 0.004097938537597656)
# Now 735 reached end
# ('elapsed time, ', 0.002279996871948242)
# Now 736 reached end
# ('elapsed time, ', 0.006739139556884766)
# Now 737 reached end
# ('elapsed time, ', 0.008222103118896484)
# Now 738 reached end
# ('elapsed time, ', 0.015295982360839844)
# Now 739 reached end
# ('elapsed time, ', 0.0039789676666259766)
# Now 740 reached end
# ('elapsed time, ', 0.009475946426391602)
# Now 741 reached end
# ('elapsed time, ', 0.009952068328857422)
# Now 742 reached end
# ('elapsed time, ', 0.024955034255981445)
# Now 743 reached end
# ('elapsed time, ', 0.0036449432373046875)
# Now 744 reached end
# ('elapsed time, ', 0.006199836730957031)
# Now 745 reached end
# ('elapsed time, ', 0.008728981018066406)
# Now 746 reached end
# ('elapsed time, ', 0.012911081314086914)
# Now 747 reached end
# ('elapsed time, ', 0.008472919464111328)
# Now 748 reached end
# ('elapsed time, ', 0.006464958190917969)
# Now 749 reached end
# ('elapsed time, ', 0.003489971160888672)
# Now 750 reached end
# ('elapsed time, ', 0.017538070678710938)
# Now 751 reached end
# ('elapsed time, ', 0.0014519691467285156)
# Now 752 reached end
# ('elapsed time, ', 0.004996061325073242)
# Now 753 reached end
# ('elapsed time, ', 0.004354000091552734)
# Now 754 reached end
# ('elapsed time, ', 0.018839120864868164)
# Now 755 reached end
# ('elapsed time, ', 0.006667137145996094)
# Now 756 reached end
# ('elapsed time, ', 0.005188941955566406)
# Now 757 reached end
# ('elapsed time, ', 0.009148120880126953)
# Now 758 reached end
# ('elapsed time, ', 0.005839109420776367)
# Now 759 reached end
# ('elapsed time, ', 0.0032351016998291016)
# Now 760 reached end
# ('elapsed time, ', 0.005187034606933594)
# Now 761 reached end
# ('elapsed time, ', 0.0140380859375)
# Now 762 reached end
# ('elapsed time, ', 0.005121946334838867)
# Now 763 reached end
# ('elapsed time, ', 0.00380706787109375)
# Now 764 reached end
# ('elapsed time, ', 0.004516124725341797)
# Now 765 reached end
# ('elapsed time, ', 0.010241031646728516)
# Now 766 reached end
# ('elapsed time, ', 0.004420042037963867)
# Now 767 reached end
# ('elapsed time, ', 0.013081073760986328)
# Now 768 reached end
# ('elapsed time, ', 0.004598855972290039)
# Now 769 reached end
# ('elapsed time, ', 0.0019299983978271484)
# Now 770 reached end
# ('elapsed time, ', 0.003378152847290039)
# Now 771 reached end
# ('elapsed time, ', 0.011184215545654297)
# Now 772 reached end
# ('elapsed time, ', 0.013989925384521484)
# Now 773 reached end
# ('elapsed time, ', 0.002074003219604492)
# Now 774 reached end
# ('elapsed time, ', 0.0029861927032470703)
# Now 775 reached end
# ('elapsed time, ', 0.0027420520782470703)
# Now 776 reached end
# ('elapsed time, ', 0.023370981216430664)
# Now 777 reached end
# ('elapsed time, ', 0.0078051090240478516)
# Now 778 reached end
# ('elapsed time, ', 0.0028519630432128906)
# Now 779 reached end
# ('elapsed time, ', 0.0068302154541015625)
# Now 780 reached end
# ('elapsed time, ', 0.003194093704223633)
# Now 781 reached end
# ('elapsed time, ', 0.0038340091705322266)
# Now 782 reached end
# ('elapsed time, ', 0.004021883010864258)
# Now 783 reached end
# ('elapsed time, ', 0.013810157775878906)
# Now 784 reached end
# ('elapsed time, ', 0.004349946975708008)
# Now 785 reached end
# ('elapsed time, ', 0.015489816665649414)
# Now 786 reached end
# ('elapsed time, ', 0.006175994873046875)
# Now 787 reached end
# ('elapsed time, ', 0.013904094696044922)
# Now 788 reached end
# ...
# Now 2034 reached end
# ('elapsed time, ', 0.005921125411987305)
# Now 2035 reached end
# ('elapsed time, ', 0.009016990661621094)
# Now 2036 reached end
# ('elapsed time, ', 0.01270294189453125)
# Now 2037 reached end
# ('elapsed time, ', 0.01583409309387207)
# Now 2038 reached end
# ('elapsed time, ', 0.03473997116088867)
# Now 2039 reached end
# ('elapsed time, ', 0.008015871047973633)
# Now 2040 reached end
# ('elapsed time, ', 0.023400068283081055)
# Now 2041 reached end
# ('elapsed time, ', 0.004414796829223633)
# Now 2042 reached end
# ('elapsed time, ', 0.015881061553955078)
# Now 2043 reached end
# ('elapsed time, ', 0.034638166427612305)
# Now 2044 reached end
# ('elapsed time, ', 0.008560895919799805)
# Now 2045 reached end
# ('elapsed time, ', 0.024884939193725586)
# Now 2046 reached end
# ('elapsed time, ', 0.01589202880859375)
# Now 2047 reached end
# ('elapsed time, ', 0.011688947677612305)
# Now 2048 reached end
# ('elapsed time, ', 0.010653972625732422)
# Now 2049 reached end
# ('elapsed time, ', 0.006562948226928711)
# Now 2050 reached end
# ('elapsed time, ', 0.0062830448150634766)
# Now 2051 reached end
# ('elapsed time, ', 0.009033203125)
# Now 2052 reached end
# ('elapsed time, ', 0.008318185806274414)
# Now 2053 reached end
# ('elapsed time, ', 0.007372856140136719)
# Now 2054 reached end
# ('elapsed time, ', 0.006410121917724609)
# Now 2055 reached end
# ('elapsed time, ', 0.0024139881134033203)
# Now 2056 reached end
# ('elapsed time, ', 0.0021169185638427734)
# Now 2057 reached end
# ('elapsed time, ', 0.006597995758056641)
# Now 2058 reached end
# ('elapsed time, ', 0.002547025680541992)
# Now 2059 reached end
# ('elapsed time, ', 0.011126995086669922)
# Now 2060 reached end
# ('elapsed time, ', 0.031948089599609375)
# Now 2061 reached end
# ('elapsed time, ', 0.00946187973022461)
# Now 2062 reached end
# ('elapsed time, ', 0.006285190582275391)
# Now 2063 reached end
# ('elapsed time, ', 0.008508920669555664)
# Now 2064 reached end
# ('elapsed time, ', 0.003220081329345703)
# Now 2065 reached end
# ('elapsed time, ', 0.016398191452026367)
# Now 2066 reached end
# ('elapsed time, ', 0.014616012573242188)
# Now 2067 reached end
# ('elapsed time, ', 0.028847932815551758)
# Now 2068 reached end
# ('elapsed time, ', 0.00793600082397461)
# Now 2069 reached end
# ('elapsed time, ', 0.005800008773803711)
# Now 2070 reached end
# ('elapsed time, ', 0.0034999847412109375)
# Now 2071 reached end
# ('elapsed time, ', 0.004261970520019531)
# Now 2072 reached end
# ('elapsed time, ', 0.00412297248840332)
# Now 2073 reached end
# ('elapsed time, ', 0.010908842086791992)
# Now 2074 reached end
# ('elapsed time, ', 0.006025075912475586)
# Now 2075 reached end
# ('elapsed time, ', 0.005072832107543945)
# Now 2076 reached end
# ('elapsed time, ', 0.006939888000488281)
# Now 2077 reached end
# ('elapsed time, ', 0.021203994750976562)
# Now 2078 reached end
# ('elapsed time, ', 0.005797147750854492)
# Now 2079 reached end
# ('elapsed time, ', 0.0067348480224609375)
# Now 2080 reached end
# ('elapsed time, ', 0.004645109176635742)
# Now 2081 reached end
# ('elapsed time, ', 0.05112409591674805)
# Now 2082 reached end
# ('elapsed time, ', 0.10854911804199219)
# Now 2083 reached end
# ('elapsed time, ', 0.006557941436767578)
# Now 2084 reached end
# ('elapsed time, ', 0.05240297317504883)
# Now 2085 reached end
# ('elapsed time, ', 0.03124690055847168)
# Now 2086 reached end
# ('elapsed time, ', 0.02549886703491211)
# Now 2087 reached end
# ('elapsed time, ', 0.009873151779174805)
# Now 2088 reached end
# ('elapsed time, ', 0.006705045700073242)
# Now 2089 reached end
# ('elapsed time, ', 0.02205204963684082)
# Now 2090 reached end
# ('elapsed time, ', 0.0037250518798828125)
# Now 2091 reached end
# ('elapsed time, ', 0.0238800048828125)
# Now 2092 reached end
# ('elapsed time, ', 0.005066871643066406)
# Now 2093 reached end
# ('elapsed time, ', 0.0055389404296875)
# Now 2094 reached end
# ('elapsed time, ', 0.011322975158691406)
# Now 2095 reached end
# ('elapsed time, ', 0.028301000595092773)
# Now 2096 reached end
# ('elapsed time, ', 0.009538888931274414)
# Now 2097 reached end
# ('elapsed time, ', 0.03916597366333008)
# Now 2098 reached end
# ('elapsed time, ', 0.009042024612426758)
# Now 2099 reached end
# ('elapsed time, ', 0.004945039749145508)
# Now 2100 reached end
# ('elapsed time, ', 0.007655143737792969)
# Now 2101 reached end
# ('elapsed time, ', 0.0027899742126464844)
# Now 2102 reached end
# ('elapsed time, ', 0.007210969924926758)
# Now 2103 reached end
# ('elapsed time, ', 0.0133819580078125)
# Now 2104 reached end
# ('elapsed time, ', 0.017263174057006836)
# Now 2105 reached end
# ('elapsed time, ', 0.010442018508911133)
# Now 2106 reached end
# ('elapsed time, ', 0.009634017944335938)
# Now 2107 reached end
# ('elapsed time, ', 0.007528066635131836)
# Now 2108 reached end
# ('elapsed time, ', 0.006173133850097656)
# Now 2109 reached end
# ('elapsed time, ', 0.01570415496826172)
# Now 2110 reached end
# ('elapsed time, ', 0.009222030639648438)
# Now 2111 reached end
# ('elapsed time, ', 0.01159214973449707)
# Now 2112 reached end
# ('elapsed time, ', 0.0031549930572509766)
# Now 2113 reached end
# ('elapsed time, ', 0.005795955657958984)
# Now 2114 reached end
# ('elapsed time, ', 0.016829967498779297)
# Now 2115 reached end
# ('elapsed time, ', 0.008545160293579102)
# Now 2116 reached end
# ('elapsed time, ', 0.011328935623168945)
# Now 2117 reached end
# ('elapsed time, ', 0.014062881469726562)
# Now 2118 reached end
# ('elapsed time, ', 0.0023508071899414062)
# Now 2119 reached end
# ('elapsed time, ', 0.01735687255859375)
# Now 2120 reached end
# ('elapsed time, ', 0.013108015060424805)
# Now 2121 reached end
# ('elapsed time, ', 0.010833978652954102)
# Now 2122 reached end
# ('elapsed time, ', 0.006440162658691406)
# Now 2123 reached end
# ('elapsed time, ', 0.012863874435424805)
# Now 2124 reached end
# ('elapsed time, ', 0.011035919189453125)
# Now 2125 reached end
# ('elapsed time, ', 0.0037119388580322266)
# Now 2126 reached end
# ('elapsed time, ', 0.006943941116333008)
# Now 2127 reached end
# ('elapsed time, ', 0.015340089797973633)
# Now 2128 reached end
# ('elapsed time, ', 0.009446859359741211)
# Now 2129 reached end
# ('elapsed time, ', 0.010864019393920898)
# Now 2130 reached end
# ('elapsed time, ', 0.006784915924072266)
# Now 2131 reached end
# ('elapsed time, ', 0.021592140197753906)
# Now 2132 reached end
# ('elapsed time, ', 0.01383209228515625)
# Now 2133 reached end
# ('elapsed time, ', 0.006220102310180664)
# Now 2134 reached end
# ('elapsed time, ', 0.033158063888549805)
# Now 2135 reached end
# ('elapsed time, ', 0.03105306625366211)
# Now 2136 reached end
# ('elapsed time, ', 0.008887052536010742)
# Now 2137 reached end
# ('elapsed time, ', 0.007940053939819336)
# Now 2138 reached end
# ('elapsed time, ', 0.0070340633392333984)
# Now 2139 reached end
# ('elapsed time, ', 0.010050058364868164)
# Now 2140 reached end
# ('elapsed time, ', 0.009546041488647461)
# Now 2141 reached end
# ('elapsed time, ', 0.012745141983032227)
# Now 2142 reached end
# ('elapsed time, ', 0.007049083709716797)
# Now 2143 reached end
# ('elapsed time, ', 0.007269859313964844)
# Now 2144 reached end
# ('elapsed time, ', 0.007708072662353516)
# Now 2145 reached end
# ('elapsed time, ', 0.004069805145263672)
# Now 2146 reached end
# ('elapsed time, ', 0.007879972457885742)
# Now 2147 reached end
# ('elapsed time, ', 0.013599157333374023)
# Now 2148 reached end
# ('elapsed time, ', 0.015253067016601562)
# Now 2149 reached end
# ('elapsed time, ', 0.005815029144287109)
# Now 2150 reached end
# ('elapsed time, ', 0.006236076354980469)
# Now 2151 reached end
# ('elapsed time, ', 0.015012025833129883)
# Now 2152 reached end
# ('elapsed time, ', 0.009785890579223633)
# Now 2153 reached end
# ('elapsed time, ', 0.01178884506225586)
# Now 2154 reached end
# ('elapsed time, ', 0.03769111633300781)
# Now 2155 reached end
# ('elapsed time, ', 0.0062749385833740234)
# Now 2156 reached end
# ('elapsed time, ', 0.00423884391784668)
# Now 2157 reached end
# ('elapsed time, ', 0.01102900505065918)
# Now 2158 reached end
# ('elapsed time, ', 0.009487152099609375)
# Now 2159 reached end
# ('elapsed time, ', 0.006261110305786133)
# Now 2160 reached end
# ('elapsed time, ', 0.003773927688598633)
# Now 2161 reached end
# ('elapsed time, ', 0.008383035659790039)
# Now 2162 reached end
# ('elapsed time, ', 0.017444849014282227)
# Now 2163 reached end
# ('elapsed time, ', 0.007534027099609375)
# Now 2164 reached end
# ('elapsed time, ', 0.009423971176147461)
# Now 2165 reached end
# ('elapsed time, ', 0.005174160003662109)
# Now 2166 reached end
# ('elapsed time, ', 0.006968021392822266)
# Now 2167 reached end
# ('elapsed time, ', 0.005671977996826172)
# Now 2168 reached end
# ('elapsed time, ', 0.006563901901245117)
# Now 2169 reached end
# ('elapsed time, ', 0.004549980163574219)
# Now 2170 reached end
# ('elapsed time, ', 0.0033440589904785156)
# Now 2171 reached end
# ('elapsed time, ', 0.008852005004882812)
# Now 2172 reached end
# ('elapsed time, ', 0.009196996688842773)
# Now 2173 reached end
# ('elapsed time, ', 0.0031881332397460938)
# Now 2174 reached end
# ('elapsed time, ', 0.007508993148803711)
# Now 2175 reached end
# ('elapsed time, ', 0.004426002502441406)
# Now 2176 reached end
# ('elapsed time, ', 0.005172014236450195)
# Now 2177 reached end
# ('elapsed time, ', 0.00619816780090332)
# Now 2178 reached end
# ('elapsed time, ', 0.02268695831298828)
# Now 2179 reached end
# ('elapsed time, ', 0.001425027847290039)
# Now 2180 reached end
# ('elapsed time, ', 0.01270604133605957)
# Now 2181 reached end
# ('elapsed time, ', 0.00902700424194336)
# Now 2182 reached end
# ('elapsed time, ', 0.013559818267822266)
# Now 2183 reached end
# ('elapsed time, ', 0.007006168365478516)
# Now 2184 reached end
# ('elapsed time, ', 0.006042957305908203)
# Now 2185 reached end
# ('elapsed time, ', 0.007274150848388672)
# Now 2186 reached end
# ('elapsed time, ', 0.01648998260498047)
# Now 2187 reached end
# ('elapsed time, ', 0.006852865219116211)
# Now 2188 reached end
# ('elapsed time, ', 0.00806117057800293)
# Now 2189 reached end
# ('elapsed time, ', 0.021236896514892578)
# Now 2190 reached end
# ('elapsed time, ', 0.023768901824951172)
# Now 2191 reached end
# ('elapsed time, ', 0.008370161056518555)
# Now 2192 reached end
# ('elapsed time, ', 0.008996009826660156)
# Now 2193 reached end
# ('elapsed time, ', 0.013882875442504883)
# Now 2194 reached end
# ('elapsed time, ', 0.02524113655090332)
# Now 2195 reached end
# ('elapsed time, ', 0.011088132858276367)
# Now 2196 reached end
# ('elapsed time, ', 0.0034542083740234375)
# Now 2197 reached end
# ('elapsed time, ', 0.0182192325592041)
# Now 2198 reached end
# ('elapsed time, ', 0.012929916381835938)
# Now 2199 reached end
# ('elapsed time, ', 0.01764392852783203)
# Now 2200 reached end
# ('elapsed time, ', 0.015626907348632812)
# Now 2201 reached end
# ('elapsed time, ', 0.01696610450744629)
# Now 2202 reached end
# ('elapsed time, ', 0.014571905136108398)
# Now 2203 reached end
# ('elapsed time, ', 0.0020809173583984375)
# Now 2204 reached end
# ('elapsed time, ', 0.005682945251464844)
# Now 2205 reached end
# ('elapsed time, ', 0.013273000717163086)
# Now 2206 reached end
# ('elapsed time, ', 0.011762857437133789)
# Now 2207 reached end
# ('elapsed time, ', 0.0035109519958496094)
# Now 2208 reached end
# ('elapsed time, ', 0.020328044891357422)
# Now 2209 reached end
# ('elapsed time, ', 0.009310007095336914)
# Now 2210 reached end
# ('elapsed time, ', 0.00503087043762207)
# Now 2211 reached end
# ('elapsed time, ', 0.01604294776916504)
# Now 2212 reached end
# ('elapsed time, ', 0.007802009582519531)
# Now 2213 reached end
# ('elapsed time, ', 0.002544879913330078)
# Now 2214 reached end
# ('elapsed time, ', 0.015351057052612305)
# Now 2215 reached end
# ('elapsed time, ', 0.008394956588745117)
# Now 2216 reached end
# ('elapsed time, ', 0.019443035125732422)
# Now 2217 reached end
# ('elapsed time, ', 0.010354995727539062)
# Now 2218 reached end
# ('elapsed time, ', 0.011529922485351562)
# Now 2219 reached end
# ('elapsed time, ', 0.010750055313110352)
# Now 2220 reached end
# ('elapsed time, ', 0.007447957992553711)
# Now 2221 reached end
# ('elapsed time, ', 0.011513948440551758)
# Now 2222 reached end
# ('elapsed time, ', 0.014282941818237305)
# Now 2223 reached end
# ('elapsed time, ', 0.034017086029052734)
# Now 2224 reached end
# ('elapsed time, ', 0.018966197967529297)
# Now 2225 reached end
# ('elapsed time, ', 0.016199111938476562)
# Now 2226 reached end
# ('elapsed time, ', 0.0016658306121826172)
# Now 2227 reached end
# ('elapsed time, ', 0.013267040252685547)
# Now 2228 reached end
# ('elapsed time, ', 0.015062093734741211)
# Now 2229 reached end
# ('elapsed time, ', 0.005209922790527344)
# Now 2230 reached end
# ('elapsed time, ', 0.008208990097045898)
# Now 2231 reached end
# ('elapsed time, ', 0.0040781497955322266)
# Now 2232 reached end
# ('elapsed time, ', 0.012336969375610352)
# Now 2233 reached end
# ('elapsed time, ', 0.00935220718383789)
# Now 2234 reached end
# ('elapsed time, ', 0.007422924041748047)
# Now 2235 reached end
# ('elapsed time, ', 0.011362075805664062)
# Now 2236 reached end
# ('elapsed time, ', 0.012742042541503906)
# Now 2237 reached end
# ('elapsed time, ', 0.015729904174804688)
# Now 2238 reached end
# ('elapsed time, ', 0.01059103012084961)
# Now 2239 reached end
# ('elapsed time, ', 0.007762908935546875)
# Now 2240 reached end
# ('elapsed time, ', 0.015186071395874023)
# Now 2241 reached end
# ('elapsed time, ', 0.0091400146484375)
# Now 2242 reached end
# ('elapsed time, ', 0.007185220718383789)
# Now 2243 reached end
# ('elapsed time, ', 0.010113000869750977)
# Now 2244 reached end
# ('elapsed time, ', 0.014416217803955078)
# Now 2245 reached end
# ('elapsed time, ', 0.043501853942871094)
# Now 2246 reached end
# ('elapsed time, ', 0.0073490142822265625)
# Now 2247 reached end
# ('elapsed time, ', 0.01625800132751465)
# Now 2248 reached end
# ('elapsed time, ', 0.008922100067138672)
# Now 2249 reached end
# ('elapsed time, ', 0.04341697692871094)
# Now 2250 reached end
# ('elapsed time, ', 0.04472184181213379)
# Now 2251 reached end
# ('elapsed time, ', 0.024188995361328125)
# Now 2252 reached end
# ('elapsed time, ', 0.020483016967773438)
# Now 2253 reached end
# ('elapsed time, ', 0.007402181625366211)
# Now 2254 reached end
# ('elapsed time, ', 0.006042003631591797)
# Now 2255 reached end
# ('elapsed time, ', 0.010072946548461914)
# Now 2256 reached end
# ('elapsed time, ', 0.004176139831542969)
# Now 2257 reached end
# ('elapsed time, ', 0.006926059722900391)
# Now 2258 reached end
# ('elapsed time, ', 0.006124019622802734)
# Now 2259 reached end
# ('elapsed time, ', 0.008534908294677734)
# Now 2260 reached end
# ('elapsed time, ', 0.006627082824707031)
# Now 2261 reached end
# ('elapsed time, ', 0.005056142807006836)
# Now 2262 reached end
# ('elapsed time, ', 0.009296178817749023)
# Now 2263 reached end
# ('elapsed time, ', 0.008803129196166992)
# Now 2264 reached end
# ('elapsed time, ', 0.006999015808105469)
# Now 2265 reached end
# ('elapsed time, ', 0.005959987640380859)
# Now 2266 reached end
# ('elapsed time, ', 0.00481104850769043)
# Now 2267 reached end
# ('elapsed time, ', 0.004859209060668945)
# Now 2268 reached end
# ('elapsed time, ', 0.02544093132019043)
# Now 2269 reached end
# ('elapsed time, ', 0.011898040771484375)
# Now 2270 reached end
# ('elapsed time, ', 0.01960897445678711)
# Now 2271 reached end
# ('elapsed time, ', 0.016086101531982422)
# Now 2272 reached end
# ('elapsed time, ', 0.010589122772216797)
# Now 2273 reached end
# ('elapsed time, ', 0.006255149841308594)
# Now 2274 reached end
# ('elapsed time, ', 0.0033431053161621094)
# Now 2275 reached end
# ('elapsed time, ', 0.004461050033569336)
# Now 2276 reached end
# ('elapsed time, ', 0.015891075134277344)
# Now 2277 reached end
# ('elapsed time, ', 0.011260032653808594)
# Now 2278 reached end
# ('elapsed time, ', 0.014395952224731445)
# Now 2279 reached end
# ('elapsed time, ', 0.009290933609008789)
# Now 2280 reached end
# ('elapsed time, ', 0.004576206207275391)
# Now 2281 reached end
# ('elapsed time, ', 0.008693933486938477)
# Now 2282 reached end
# ('elapsed time, ', 0.005549907684326172)
# Now 2283 reached end
# ('elapsed time, ', 0.009448051452636719)
# Now 2284 reached end
# ('elapsed time, ', 0.004386186599731445)
# Now 2285 reached end
# ('elapsed time, ', 0.00430607795715332)
# Now 2286 reached end
# ('elapsed time, ', 0.013438940048217773)
# Now 2287 reached end
# ('elapsed time, ', 0.00689697265625)
# Now 2288 reached end
# ('elapsed time, ', 0.0038030147552490234)
# Now 2289 reached end
# ('elapsed time, ', 0.004667997360229492)
# Now 2290 reached end
# ('elapsed time, ', 0.0035219192504882812)
# Now 2291 reached end
# ('elapsed time, ', 0.019101858139038086)
# Now 2292

# %% [markdown]
# ## Lets see the heatmap of Q values

# %%
heatmap(Q.max(2))

# %% [markdown]
# # Determine the policy

# %%
policy = Q.argmax(2)
policy
# Out:
# array([[3, 2, 1, 3, 2, 3, 1, 1, 1, 2],
#        [2, 2, 1, 2, 1, 3, 2, 2, 0, 0],
#        [2, 1, 3, 0, 1, 1, 1, 3, 3, 0],
#        [3, 1, 0, 3, 2, 0, 1, 2, 1, 0],
#        [0, 1, 3, 2, 1, 2, 0, 3, 3, 3],
#        [3, 0, 2, 0, 3, 3, 3, 0, 1, 0],
#        [0, 1, 3, 3, 1, 1, 1, 3, 3, 0],
#        [0, 2, 2, 2, 3, 2, 3, 3, 0, 1],
#        [0, 3, 3, 3, 1, 0, 3, 3, 3, 1],
#        [3, 2, 0, 1, 2, 1, 0, 3, 1, 2]])

# %% [markdown]
# # Test the policy

# %%
#test policy
start_state = (0,0)
end_state= (9,9)
current_state = (0,0)

while current_state != end_state:
    action = policy[current_state[0], current_state[1]]
    actual_next_action, next_state = step(current_state, action)
    print "current_state", current_state, "action", actions[action], "actual_action", actions[actual_next_action]
    current_state = next_state
# Out:
# current_state (0, 0) action left actual_action right
# current_state (0, 1) action down actual_action down
# current_state (1, 1) action down actual_action up
# current_state (0, 1) action down actual_action down
# current_state (1, 1) action down actual_action up
# current_state (0, 1) action down actual_action left
# current_state (0, 0) action left actual_action down
# current_state (1, 0) action down actual_action right
# current_state (1, 1) action down actual_action up
# current_state (0, 1) action down actual_action left
# current_state (0, 0) action left actual_action down
# current_state (1, 0) action down actual_action down
# current_state (2, 0) action down actual_action down
# current_state (3, 0) action left actual_action up
# current_state (2, 0) action down actual_action down
# current_state (3, 0) action left actual_action down
# current_state (4, 0) action up actual_action down
# current_state (5, 0) action left actual_action up
# current_state (4, 0) action up actual_action down
# current_state (5, 0) action left actual_action up
# current_state (4, 0) action up actual_action right
# current_state (4, 1) action right actual_action up
# current_state (3, 1) action right actual_action down
# current_state (4, 1) action right actual_action left
# current_state (4, 0) action up actual_action down
# current_state (5, 0) action left actual_action up
# current_state (4, 0) action up actual_action right
# current_state (4, 1) action right actual_action left
# current_state (4, 0) action up actual_action down
# current_state (5, 0) action left actual_action up
# current_state (4, 0) action up actual_action down
# current_state (5, 0) action left actual_action up
# current_state (4, 0) action up actual_action right
# current_state (4, 1) action right actual_action up
# current_state (3, 1) action right actual_action down
# current_state (4, 1) action right actual_action up
# current_state (3, 1) action right actual_action up
# current_state (2, 1) action right actual_action up
# current_state (1, 1) action down actual_action up
# current_state (0, 1) action down actual_action left
# current_state (0, 0) action left actual_action down
# current_state (1, 0) action down actual_action down
# current_state (2, 0) action down actual_action up
# current_state (1, 0) action down actual_action up
# current_state (0, 0) action left actual_action right
# current_state (0, 1) action down actual_action right
# current_state (0, 2) action right actual_action down
# current_state (1, 2) action right actual_action up
# current_state (0, 2) action right actual_action down
# current_state (1, 2) action right actual_action left
# current_state (1, 1) action down actual_action left
# current_state (1, 0) action down actual_action up
# current_state (0, 0) action left actual_action down
# current_state (1, 0) action down actual_action down
# current_state (2, 0) action down actual_action up
# current_state (1, 0) action down actual_action down
# current_state (2, 0) action down actual_action right
# current_state (2, 1) action right actual_action left
# current_state (2, 0) action down actual_action up
# current_state (1, 0) action down actual_action up
# current_state (0, 0) action left actual_action down
# current_state (1, 0) action down actual_action up
# current_state (0, 0) action left actual_action down
# current_state (1, 0) action down actual_action down
# current_state (2, 0) action down actual_action right
# current_state (2, 1) action right actual_action right
# current_state (2, 2) action left actual_action down
# current_state (3, 2) action up actual_action left
# current_state (3, 1) action right actual_action left
# current_state (3, 0) action left actual_action down
# current_state (4, 0) action up actual_action down
# current_state (5, 0) action left actual_action down
# current_state (6, 0) action up actual_action right
# current_state (6, 1) action right actual_action right
# current_state (6, 2) action left actual_action down
# current_state (7, 2) action down actual_action down
# current_state (8, 2) action left actual_action left
# current_state (8, 1) action left actual_action right
# current_state (8, 2) action left actual_action right
# current_state (8, 3) action left actual_action down
# current_state (9, 3) action right actual_action left
# current_state (9, 2) action up actual_action right
# current_state (9, 3) action right actual_action left
# current_state (9, 2) action up actual_action right
# current_state (9, 3) action right actual_action left
# current_state (9, 2) action up actual_action left
# current_state (9, 1) action down actual_action right
# current_state (9, 2) action up actual_action right
# current_state (9, 3) action right actual_action right
# current_state (9, 4) action down actual_action up
# current_state (8, 4) action right actual_action down
# current_state (9, 4) action down actual_action right
# current_state (9, 5) action right actual_action right
# current_state (9, 6) action up actual_action up
# current_state (8, 6) action left actual_action down
# current_state (9, 6) action up actual_action left
# current_state (9, 5) action right actual_action up
# current_state (8, 5) action up actual_action down
# current_state (9, 5) action right actual_action right
# current_state (9, 6) action up actual_action right
# current_state (9, 7) action left actual_action right
# current_state (9, 8) action right actual_action right
